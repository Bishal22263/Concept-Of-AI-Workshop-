# %%
import pandas as pd
import os

# Problem 1 - Data Read, Write and Inspect:

# 1
df = pd.read_csv('/content/drive/MyDrive/AI/bank.csv')
print(df.head())

# 2
# a columns with dtypes=object
object_columns = df.select_dtypes(include='object').columns
print("columns with dtypes=object: ", object_columns.tolist() )

# b unique values of those columns.
for col in object_columns:
    print(f"\nUnique values in '{col}': {df[col].unique()}")

# C heck for the total number of null values in each column.
print("Null values in each column:")
print(df.isnull().sum())

# 3
df_numeric = df.select_dtypes(exclude='object')
print("Numeric-only DataFrame created!")
print("Remaining columns:", df_numeric.columns.tolist())
df_numeric.head()
df_numeric.to_csv("banknumericdata.csv", index=False)
print("File saved as 'banknumericdata.csv'")

# 4

df_new = pd.read_csv("banknumericdata.csv")
print("banknumericdata.csv loaded successfully!")
df_new.head()
print("Summary Statistics of Numeric Data:")
df_new.describe()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
# ...

# %%
import pandas as pd

# Problem 2 - Data Imputations:

# 1) Load the provided dataset and import in pandas DataFrame.
# ANS:
df = pd.read_csv('/content/drive/MyDrive/AI/medical_students_dataset (1).csv')
print(df.head())

# 2) Check info of the DataFrame and identify column with missing (null) values.
# Ans:
print("info: ",df.info())
print("null checking: \n",df.isnull().sum())

''' 3)For the column with missing values fill the values using various techniques we discussed above.
Tryto explain why did you select the particular methods for particular column.
Ans:'''
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# ...

# %%
import pandas as pd

'''Problem - 1:
Create a DataFrame that is subsetted for the columns ’Name’, ’Pclass’, ’Sex’, ’Age’, ’Fare’, and ’Survived’.
Retain only those rows where ’Pclass’ is equal to 1, representing first-class passengers. What is the mean,
median, maximum value, and minimum value of the ’Fare’ column?'''

df = pd.read_csv('/content/drive/MyDrive/AI/Titanic-Dataset.csv')

# Create subset with specified columns
subset_df = df[['Name', 'Pclass', 'Sex', 'Age', 'Fare', 'Survived']]

# Filter for first-class passengers (Pclass == 1)
first_class_df = subset_df[subset_df['Pclass'] == 1]

# Calculate statistics for 'Fare'
fare_mean = first_class_df['Fare'].mean()
fare_median = first_class_df['Fare'].median()
fare_max = first_class_df['Fare'].max()
fare_min = first_class_df['Fare'].min()

# Print the results
print(f"Mean Fare: {fare_mean}")
print(f"Median Fare: {fare_median}")
print(f"Maximum Fare: {fare_max}")
print(f"Minimum Fare: {fare_min}")
# Out:
# Mean Fare: 84.1546875
# Median Fare: 60.287499999999994
# Maximum Fare: 512.3292
# Minimum Fare: 0.0

# %%
'''Problem - 2:
How many null values are contained in the ’Age’ column in your subsetted DataFrame? Once you’ve found
this out, drop them from your DataFrame.'''

df = pd.read_csv("/content/drive/MyDrive/AI/Titanic-Dataset.csv")

null_count = subset_df['Age'].isnull().sum()
print(f"Number of null values in the 'Age' column: {null_count}")
# Output: Number of null values in the 'Age' column: 30

# 2. Drop all rows that have null in the 'Age' column
subset_df = subset_df.dropna(subset=['Age'])

# Optional: Confirm they are gone
print(f"After dropping → Null values in Age: {subset_df['Age'].isnull().sum()}")
print(f"Rows remaining: {len(subset_df)}")
# Out:
# Number of null values in the 'Age' column: 177
# After dropping → Null values in Age: 0
# Rows remaining: 714

# %%
import pandas as pd

''' Problem - 3:

The ’Embarked’ column in the Titanic dataset contains categorical data representing the ports of embarka-
tion:

• ’C’ for Cherbourg
• ’Q’ for Queenstown
• ’S’ for Southampton

1.) Use one-hot encoding to convert the ’Embarked’ column into separate binary columns (’Embarked C’,
’Embarked Q’, ’Embarked S’).'''
df = pd.read_csv('/content/drive/MyDrive/AI/Titanic-Dataset.csv')

embarked_encoded = pd.get_dummies(df['Embarked'], prefix='Embarked')

# Show the result
print("One-hot encoding of 'Embarked' column completed:")
print(embarked_encoded.head(10))


# 2. Add these new columns to the original DataFrame.
df = pd.concat([df, embarked_encoded], axis=1)


print("new embarked added")
print(df[['Embarked', 'Embarked_C', 'Embarked_Q', 'Embarked_S']].head(10))

# Drop the original ’Embarked’ column.
df = df.drop('Embarked', axis=1)

# Verify it's really gone
print(" Original 'Embarked' column has been DROPPED!")
print("Current columns:", df.columns.tolist())
# Out:
# One-hot encoding of 'Embarked' column completed:
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True
# 5       False        True       False
# 6       False       False        True
# 7       False       False        True
# 8       False       False        True
# 9        True       False       False
# new embarked added
#   Embarked  Embarked_C  Embarked_Q  Embarked_S
# 0        S       False       False        True
# 1        C        True       False       False
# 2        S       False       False        True
# 3        S       False       False        True
# 4        S       False       False        True
# 5        Q       False        True       False
# 6        S       False       False        True
# 7        S       False       False        True
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


mean_survival = df.groupby('Sex')['Survived'].mean()
print("Mean Survival Rate by Gender:")
print(mean_survival)


plt.figure(figsize=(6,4))
mean_survival.plot(kind='bar')

plt.title("Mean Survival Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Survival Rate")
plt.xticks(rotation=0)

plt.show()
# Out:
# Mean Survival Rate by Gender:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64
